# %%
import sys
sys.path.insert(0, "/home/stefan/CRS/CRS.ZarrPipelines/")
from app.flows.pipeline_flow import full_pipeline, score_only, aggregate_only, combine_only
# Out:
# /home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# # Level 4 — Full pipeline via Prefect (manages Coiled clusters internally)
#
# Prefect `@flow` handles Coiled cluster lifecycle, retries, and logging.
# Each phase can also be run independently: `score_only`, `aggregate_only`, `combine_only`.

# %% [markdown]
# ## Full pipeline

# %%
# Full run for a hazard subset — score → aggregate → combine
full_pipeline(
    scales=["5", "10", "100"],
    gadm_levels=[0,1],
    hazard_codes=["TC"],   # subset for smoke test; omit hazard_codes for all 14
    #hazard_codes=["HP","HS","CS","WF","LS","ER","CER","SUB","WS","DR"],   # subset for smoke test; omit hazard_codes for all 14
)
# Out:
# 22:43:06.087 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8226
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 22:43:10.757 | INFO    | Flow run 'thankful-gaur' - Beginning flow run 'thankful-gaur' for flow 'crs-full-pipeline'
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────── Package Info ────────────────────────────────╮
# │                         ╷                                                    │
# │   Package               │ Note                                               │
# │ ╶───────────────────────┼──────────────────────────────────────────────────╴ │
# │   crs-zarrpipelines     │ Wheel built from ~/CRS/CRS.ZarrPipelines           │
# │                         ╵                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 22:46:18.800 | INFO    | distributed.deploy.adaptive - Adaptive scaling started: minimum=25 maximum=60
# 22:46:21.258 | INFO    | Task run 'score-hazard-cf1' - Found config at: /home/stefan/CRS/CRS.ZarrPipelines/app/config/scoring.yaml
# 22:46:32.621 | INFO    | Task run 'score-hazard-cf1' - Finished in state Completed()
# 22:46:33.070 | INFO    | distributed.deploy.adaptive - Adaptive scaling stopped: minimum=25 maximum=60. Reason: unknown
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────── Package Info ────────────────────────────────╮
# │                         ╷                                                    │
# │   Package               │ Note                                               │
# │ ╶───────────────────────┼──────────────────────────────────────────────────╴ │
# │   crs-zarrpipelines     │ Wheel built from ~/CRS/CRS.ZarrPipelines           │
# │                         ╵                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 22:49:08.547 | INFO    | distributed.deploy.adaptive - Adaptive scaling started: minimum=10 maximum=30
# 22:53:30.249 | INFO    | Task run 'aggregate-hazard-b5e' - Finished in state Completed()
# 22:53:30.469 | INFO    | distributed.deploy.adaptive - Adaptive scaling stopped: minimum=10 maximum=30. Reason: unknown
# 22:55:17.615 | WARNING | app.domain.combine - [CF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/CF_adm0.csv — skipping
# 22:55:19.447 | WARNING | app.domain.combine - [RF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/RF_adm0.csv — skipping
# 22:55:20.685 | INFO    | Task run 'combine-scores-118' -   scale='5' → five/
# 22:55:20.814 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 22:55:20.941 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_mean_45.csv (263 rows, 58 cols)
# 22:55:21.200 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 22:55:21.267 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_max_45.csv (263 rows, 58 cols)
# 22:55:21.514 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 22:55:21.594 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_std_45.csv (263 rows, 58 cols)
# 22:55:21.998 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_mean_85.csv (263 rows, 58 cols)
# 22:55:22.359 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_max_85.csv (263 rows, 58 cols)
# 22:55:22.757 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_std_85.csv (263 rows, 58 cols)
# 22:55:23.100 | INFO    | Task run 'combine-scores-118' -   scale='10' → ten/
# 22:55:23.164 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 22:55:23.238 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_mean_45.csv (263 rows, 58 cols)
# 22:55:23.573 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 22:55:23.664 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_max_45.csv (263 rows, 58 cols)
# 22:55:24.001 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 22:55:24.073 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_std_45.csv (263 rows, 58 cols)
# 22:55:24.482 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_mean_85.csv (263 rows, 58 cols)
# 22:55:24.792 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_max_85.csv (263 rows, 58 cols)
# 22:55:25.115 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_std_85.csv (263 rows, 58 cols)
# 22:55:25.352 | INFO    | Task run 'combine-scores-118' -   scale='100' → hundred/
# 22:55:25.404 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 22:55:25.644 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_mean_45.csv (263 rows, 58 cols)
# 22:55:25.927 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_mean_85.csv (263 rows, 58 cols)
# 22:55:26.232 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 22:55:26.433 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_max_45.csv (263 rows, 58 cols)
# 22:55:26.703 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_max_85.csv (263 rows, 58 cols)
# 22:55:26.985 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 22:55:27.200 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_std_45.csv (263 rows, 58 cols)
# 22:55:27.490 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_std_85.csv (263 rows, 58 cols)
# 22:58:42.160 | WARNING | app.domain.combine - [CF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/CF_adm1.csv — skipping
# 22:58:54.888 | WARNING | app.domain.combine - [RF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/RF_adm1.csv — skipping
# 22:59:02.612 | INFO    | Task run 'combine-scores-118' -   scale='5' → five/
# 22:59:03.026 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 22:59:03.425 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_mean_45.csv (3662 rows, 62 cols)
# 22:59:04.409 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 22:59:04.582 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_max_45.csv (3662 rows, 62 cols)
# 22:59:05.585 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 22:59:05.767 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_std_45.csv (3662 rows, 62 cols)
# 22:59:07.491 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_mean_85.csv (3662 rows, 62 cols)
# 22:59:08.903 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_max_85.csv (3662 rows, 62 cols)
# 22:59:10.969 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_std_85.csv (3662 rows, 62 cols)
# 22:59:12.389 | INFO    | Task run 'combine-scores-118' -   scale='10' → ten/
# 22:59:12.655 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 22:59:12.847 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_mean_45.csv (3662 rows, 62 cols)
# 22:59:13.978 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 22:59:14.190 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_max_45.csv (3662 rows, 62 cols)
# 22:59:15.405 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 22:59:15.651 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_std_45.csv (3662 rows, 62 cols)
# 22:59:17.679 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_mean_85.csv (3662 rows, 62 cols)
# 22:59:19.078 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_max_85.csv (3662 rows, 62 cols)
# 22:59:20.212 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_std_85.csv (3662 rows, 62 cols)
# 22:59:21.615 | INFO    | Task run 'combine-scores-118' -   scale='100' → hundred/
# 22:59:21.889 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 22:59:22.522 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_mean_45.csv (3662 rows, 62 cols)
# 22:59:23.764 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_mean_85.csv (3662 rows, 62 cols)
# 22:59:25.218 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 22:59:25.814 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_max_45.csv (3662 rows, 62 cols)
# 22:59:27.101 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_max_85.csv (3662 rows, 62 cols)
# 22:59:28.576 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 22:59:29.131 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_std_45.csv (3662 rows, 62 cols)
# 22:59:31.258 | INFO    | Task run 'combine-scores-118' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_std_85.csv (3662 rows, 62 cols)
# 22:59:32.841 | INFO    | Task run 'combine-scores-118' - Finished in state Completed()
# 22:59:33.129 | INFO    | Flow run 'thankful-gaur' - Finished in state Completed()

# %% [markdown]
# # Run individual phases (examples)

# %% [markdown]
# ## Score only

# %%
score_only(scales=["5","10","100"], hazard_codes=["RF"])       # add/replace one scale

# %% [markdown]
# ## Aggregate Only

# %%
aggregate_only(gadm_levels=[0,1], hazard_codes=["HP","HS","CS","WF","LS","ER","CER","SUB","WS","DR","TC","TS"])  # re-aggregate after rescoring

# %%
import fsspec, pandas as pd
with fsspec.open("gs://crs_climate_data_public/production_test/aggregations/SUB_adm1.csv") as f:
    df = pd.read_csv(f)
print(df["scenario"].unique())
print(df["scoring"].unique())
# Out:
# <ArrowStringArray>
# ['RCP85']
# Length: 1, dtype: str
# [ 10 100   5]

# %% [markdown]
# ## Combine Only

# %% [markdown]
# ## Rebuild combined final output from all existing individual hazard CSVs only

# %%
combine_only(gadm_levels=[0,1], scales=["5","10","100"])
