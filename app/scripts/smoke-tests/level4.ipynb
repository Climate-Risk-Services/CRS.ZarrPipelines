# %%
import sys
sys.path.insert(0, "/home/stefan/CRS/CRS.ZarrPipelines/")
from app.flows.pipeline_flow import full_pipeline, score_only, aggregate_only, combine_only
# Out:
# /home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# # Level 4 — Full pipeline via Prefect (manages Coiled clusters internally)
#
# Prefect `@flow` handles Coiled cluster lifecycle, retries, and logging.
# Each phase can also be run independently: `score_only`, `aggregate_only`, `combine_only`.

# %% [markdown]
# ## Full pipeline

# %%
# Full run for a hazard subset — score → aggregate → combine
full_pipeline(
    scales=["5", "10", "100"],
    gadm_levels=[0,1],
    hazard_codes=["WF"],   # subset for smoke test; omit hazard_codes for all 14
    #hazard_codes=["HP","HS","CS","WF","LS","ER","CER","SUB","WS","DR"],   # subset for smoke test; omit hazard_codes for all 14
)
# Out:
# 01:18:59.776 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8210
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 01:19:04.433 | INFO    | Flow run 'pretty-squid' - Beginning flow run 'pretty-squid' for flow 'crs-full-pipeline'
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────── Package Info ────────────────────────────────╮
# │                         ╷                                                    │
# │   Package               │ Note                                               │
# │ ╶───────────────────────┼──────────────────────────────────────────────────╴ │
# │   crs-zarrpipelines     │ Wheel built from ~/CRS/CRS.ZarrPipelines           │
# │                         ╵                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 01:22:37.658 | INFO    | distributed.deploy.adaptive - Adaptive scaling started: minimum=25 maximum=60
# 01:22:40.275 | INFO    | Task run 'score-hazard-527' - Found config at: /home/stefan/CRS/CRS.ZarrPipelines/app/config/scoring.yaml
# 01:29:27.698 | INFO    | Task run 'score-hazard-527' - Finished in state Completed()
# 01:29:27.930 | INFO    | distributed.deploy.adaptive - Adaptive scaling stopped: minimum=25 maximum=60. Reason: unknown
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────── Package Info ────────────────────────────────╮
# │                         ╷                                                    │
# │   Package               │ Note                                               │
# │ ╶───────────────────────┼──────────────────────────────────────────────────╴ │
# │   crs-zarrpipelines     │ Wheel built from ~/CRS/CRS.ZarrPipelines           │
# │                         ╵                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 01:32:03.815 | INFO    | distributed.deploy.adaptive - Adaptive scaling started: minimum=10 maximum=30
# 01:45:56.407 | INFO    | Task run 'aggregate-hazard-34c' - Finished in state Completed()
# 01:45:56.415 | INFO    | distributed.deploy.adaptive - Adaptive scaling stopped: minimum=10 maximum=30. Reason: unknown
# 01:47:47.738 | WARNING | app.domain.combine - [CF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/CF_adm0.csv — skipping
# 01:47:50.049 | WARNING | app.domain.combine - [RF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/RF_adm0.csv — skipping
# 01:47:51.457 | INFO    | Task run 'combine-scores-70e' -   scale='5' → five/
# 01:47:51.559 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:47:51.645 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_mean_45.csv (263 rows, 58 cols)
# 01:47:52.022 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:47:52.112 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_max_45.csv (263 rows, 58 cols)
# 01:47:52.371 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:47:52.440 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_std_45.csv (263 rows, 58 cols)
# 01:47:52.825 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_mean_85.csv (263 rows, 58 cols)
# 01:47:53.167 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_max_85.csv (263 rows, 58 cols)
# 01:47:53.492 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_std_85.csv (263 rows, 58 cols)
# 01:47:53.727 | INFO    | Task run 'combine-scores-70e' -   scale='10' → ten/
# 01:47:53.803 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:47:53.881 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_mean_45.csv (263 rows, 58 cols)
# 01:47:54.206 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:47:54.305 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_max_45.csv (263 rows, 58 cols)
# 01:47:54.604 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:47:55.055 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_std_45.csv (263 rows, 58 cols)
# 01:47:55.489 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_mean_85.csv (263 rows, 58 cols)
# 01:47:55.926 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_max_85.csv (263 rows, 58 cols)
# 01:47:56.273 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_std_85.csv (263 rows, 58 cols)
# 01:47:56.499 | INFO    | Task run 'combine-scores-70e' -   scale='100' → hundred/
# 01:47:56.560 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:47:56.819 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_mean_45.csv (263 rows, 58 cols)
# 01:47:57.122 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_mean_85.csv (263 rows, 58 cols)
# 01:47:57.422 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:47:57.674 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_max_45.csv (263 rows, 58 cols)
# 01:47:57.946 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_max_85.csv (263 rows, 58 cols)
# 01:47:58.244 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:47:58.482 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_std_45.csv (263 rows, 58 cols)
# 01:47:58.765 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_std_85.csv (263 rows, 58 cols)
# 01:50:09.631 | WARNING | app.domain.combine - [CF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/CF_adm1.csv — skipping
# 01:50:24.650 | WARNING | app.domain.combine - [RF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/RF_adm1.csv — skipping
# 01:50:31.832 | INFO    | Task run 'combine-scores-70e' -   scale='5' → five/
# 01:50:32.137 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:50:32.328 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_mean_45.csv (3662 rows, 62 cols)
# 01:50:33.394 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:50:33.575 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_max_45.csv (3662 rows, 62 cols)
# 01:50:34.570 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:50:34.746 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_std_45.csv (3662 rows, 62 cols)
# 01:50:36.495 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_mean_85.csv (3662 rows, 62 cols)
# 01:50:37.638 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_max_85.csv (3662 rows, 62 cols)
# 01:50:38.786 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_std_85.csv (3662 rows, 62 cols)
# 01:50:40.194 | INFO    | Task run 'combine-scores-70e' -   scale='10' → ten/
# 01:50:40.449 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:50:40.628 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_mean_45.csv (3662 rows, 62 cols)
# 01:50:41.623 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:50:41.816 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_max_45.csv (3662 rows, 62 cols)
# 01:50:42.811 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:50:42.981 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_std_45.csv (3662 rows, 62 cols)
# 01:50:44.817 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_mean_85.csv (3662 rows, 62 cols)
# 01:50:46.026 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_max_85.csv (3662 rows, 62 cols)
# 01:50:47.198 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_std_85.csv (3662 rows, 62 cols)
# 01:50:48.701 | INFO    | Task run 'combine-scores-70e' -   scale='100' → hundred/
# 01:50:48.949 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:50:49.600 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_mean_45.csv (3662 rows, 62 cols)
# 01:50:50.907 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_mean_85.csv (3662 rows, 62 cols)
# 01:50:52.395 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:50:53.026 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_max_45.csv (3662 rows, 62 cols)
# 01:50:54.345 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_max_85.csv (3662 rows, 62 cols)
# 01:50:56.254 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:50:57.004 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_std_45.csv (3662 rows, 62 cols)
# 01:50:58.560 | INFO    | Task run 'combine-scores-70e' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_std_85.csv (3662 rows, 62 cols)
# 01:50:59.824 | INFO    | Task run 'combine-scores-70e' - Finished in state Completed()
# 01:50:59.850 | INFO    | Flow run 'pretty-squid' - Finished in state Completed()

# %% [markdown]
# # Run individual phases (examples)

# %% [markdown]
# ## Score only

# %%
score_only(scales=["5","10","100"], hazard_codes=["RF"])       # add/replace one scale

# %% [markdown]
# ## Aggregate Only

# %%
aggregate_only(gadm_levels=[0,1], hazard_codes=["HP","HS","CS","WF","LS","ER","CER","SUB","WS","DR","TC","TS"])  # re-aggregate after rescoring

# %%
import fsspec, pandas as pd
with fsspec.open("gs://crs_climate_data_public/production_test/aggregations/SUB_adm1.csv") as f:
    df = pd.read_csv(f)
print(df["scenario"].unique())
print(df["scoring"].unique())
# Out:
# <ArrowStringArray>
# ['RCP85']
# Length: 1, dtype: str
# [ 10 100   5]

# %% [markdown]
# ## Combine Only

# %% [markdown]
# ## Rebuild combined final output from all existing individual hazard CSVs only

# %%
combine_only(gadm_levels=[0,1], scales=["5","10","100"])
