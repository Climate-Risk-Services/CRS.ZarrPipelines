# %%
import sys
sys.path.insert(0, "/home/stefan/CRS/CRS.ZarrPipelines/")
from app.flows.pipeline_flow import full_pipeline, score_only, aggregate_only, combine_only
# Out:
# /home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# # Level 4 — Full pipeline via Prefect (manages Coiled clusters internally)
#
# Prefect `@flow` handles Coiled cluster lifecycle, retries, and logging.
# Each phase can also be run independently: `score_only`, `aggregate_only`, `combine_only`.

# %% [markdown]
# ## Full pipeline

# %%
# Full run for a hazard subset — score → aggregate → combine
full_pipeline(
    scales=["5", "10", "100"],
    gadm_levels=[0,1],
    hazard_codes=["TS"],   # subset for smoke test; omit hazard_codes for all 14
    #hazard_codes=["HP","HS","CS","WF","LS","ER","CER","SUB","WS","DR"],   # subset for smoke test; omit hazard_codes for all 14
)
# Out:
# 18:08:01.292 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8584
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 18:08:07.236 | INFO    | Flow run 'stirring-bloodhound' - Beginning flow run 'stirring-bloodhound' for flow 'crs-full-pipeline'
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────── Package Info ────────────────────────────────╮
# │                         ╷                                                    │
# │   Package               │ Note                                               │
# │ ╶───────────────────────┼──────────────────────────────────────────────────╴ │
# │   crs-zarrpipelines     │ Wheel built from ~/CRS/CRS.ZarrPipelines           │
# │                         ╵                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 18:10:56.575 | INFO    | distributed.deploy.adaptive - Adaptive scaling started: minimum=25 maximum=60
# 18:10:59.251 | INFO    | Task run 'score-hazard-214' - Found config at: /home/stefan/CRS/CRS.ZarrPipelines/app/config/scoring.yaml
# 18:11:20.475 | INFO    | Task run 'score-hazard-214' - Finished in state Completed()
# 18:11:21.460 | INFO    | distributed.deploy.adaptive - Adaptive scaling stopped: minimum=25 maximum=60. Reason: unknown
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────── Package Info ────────────────────────────────╮
# │                         ╷                                                    │
# │   Package               │ Note                                               │
# │ ╶───────────────────────┼──────────────────────────────────────────────────╴ │
# │   crs-zarrpipelines     │ Wheel built from ~/CRS/CRS.ZarrPipelines           │
# │                         ╵                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 18:14:29.460 | INFO    | distributed.deploy.adaptive - Adaptive scaling started: minimum=10 maximum=30
# 18:20:26.687 | INFO    | Task run 'aggregate-hazard-e05' - Finished in state Completed()
# 18:20:26.697 | INFO    | distributed.deploy.adaptive - Adaptive scaling stopped: minimum=10 maximum=30. Reason: unknown

# %% [markdown]
# # Score only

# %%
score_only(scales=["5","10","100"], hazard_codes=["RF"])       # add/replace one scale
# Out:
# 02:10:17.200 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8390
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 02:10:22.176 | INFO    | Flow run 'peculiar-bloodhound' - Beginning flow run 'peculiar-bloodhound' for flow 'crs-score-only'
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────── Package Info ────────────────────────────────╮
# │                         ╷                                                    │
# │   Package               │ Note                                               │
# │ ╶───────────────────────┼──────────────────────────────────────────────────╴ │
# │   crs-zarrpipelines     │ Wheel built from ~/CRS/CRS.ZarrPipelines           │
# │                         ╵                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 02:13:04.092 | INFO    | distributed.deploy.adaptive - Adaptive scaling started: minimum=25 maximum=60
# 02:13:06.742 | INFO    | Task run 'score-hazard-fb5' - Found config at: /home/stefan/CRS/CRS.ZarrPipelines/app/config/scoring.yaml
# 02:15:30.343 | INFO    | Task run 'score-hazard-fb5' - Task run failed with exception: ValueError('buffer source array is read-only') - Retry 1/2 will start 30 second(s) from now
# 02:16:01.018 | INFO    | Task run 'score-hazard-fb5' - Found config at: /home/stefan/CRS/CRS.ZarrPipelines/app/config/scoring.yaml
# 02:16:12.429 | INFO    | Task run 'score-hazard-fb5' - Task run failed with exception: ValueError('buffer source array is read-only') - Retry 2/2 will start 30 second(s) from now
# 02:16:43.048 | INFO    | Task run 'score-hazard-fb5' - Found config at: /home/stefan/CRS/CRS.ZarrPipelines/app/config/scoring.yaml
# 02:16:54.012 | INFO    | distributed.deploy.adaptive - Adaptive scaling stopped: minimum=25 maximum=60. Reason: unknown
# 02:16:54.567 | ERROR   | Task run 'score-hazard-fb5' - Task run failed with exception: ValueError('buffer source array is read-only') - Retries are exhausted
# Traceback (most recent call last):
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/prefect/task_engine.py", line 1014, in run_context
#     yield self
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/prefect/task_engine.py", line 1673, in run_task_sync
#     engine.call_task_fn(txn)
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/prefect/task_engine.py", line 1031, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/prefect/utilities/callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/stefan/CRS/CRS.ZarrPipelines/app/flows/pipeline_flow.py", line 26, in score_hazard_task
#     score_hazard(hazard_code, scales=scales)
#   File "/home/stefan/CRS/CRS.ZarrPipelines/app/domain/pipeline.py", line 176, in score_hazard
#     scored = score_rf(
#              ^^^^^^^^^
#   File "/home/stefan/CRS/CRS.ZarrPipelines/app/domain/special/rf.py", line 120, in score_rf
#     adjusted_100.rename("score").to_dataset().to_zarr(minmax_path, mode="w")
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/xarray/core/dataset.py", line 2390, in to_zarr
#     return to_zarr(  # type: ignore[call-overload,misc]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/xarray/backends/writers.py", line 797, in to_zarr
#     dump_to_store(dataset, zstore, writer, encoding=encoding)
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/xarray/backends/writers.py", line 491, in dump_to_store
#     store.store(variables, attrs, check_encoding, writer, unlimited_dims=unlimited_dims)
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/xarray/backends/zarr.py", line 1064, in store
#     self.set_variables(
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/xarray/backends/zarr.py", line 1299, in set_variables
#     writer.add(v.data, zarr_array, region)
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/xarray/backends/common.py", line 401, in add
#     target[region] = source
#     ~~~~~~^^^^^^^^
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/zarr/core.py", line 1449, in __setitem__
#     self.set_basic_selection(pure_selection, value, fields=fields)
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/zarr/core.py", line 1545, in set_basic_selection
#     return self._set_basic_selection_nd(selection, value, fields=fields)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/zarr/core.py", line 1935, in _set_basic_selection_nd
#     self._set_selection(indexer, value, fields=fields)
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/zarr/core.py", line 2008, in _set_selection
#     self._chunk_setitems(lchunk_coords, lchunk_selection, chunk_values, fields=fields)
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/zarr/core.py", line 2217, in _chunk_setitems
#     to_store = {k: self._encode_chunk(v) for k, v in cdatas.items()}
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/zarr/core.py", line 2217, in <dictcomp>
#     to_store = {k: self._encode_chunk(v) for k, v in cdatas.items()}
#                    ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/zarr/core.py", line 2387, in _encode_chunk
#     chunk = f.encode(chunk)
#             ^^^^^^^^^^^^^^^
#   File "numcodecs/vlen.pyx", line 87, in numcodecs.vlen.VLenUTF8.encode
#   File "<stringsource>", line 663, in View.MemoryView.memoryview_cwrapper
#   File "<stringsource>", line 353, in View.MemoryView.memoryview.__cinit__
# ValueError: buffer source array is read-only
# 02:16:54.593 | ERROR   | Task run 'score-hazard-fb5' - Finished in state Failed('Task run encountered an exception ValueError: buffer source array is read-only')
# 02:16:54.601 | ERROR   | Flow run 'peculiar-bloodhound' - Crash detected! Execution was aborted by an interrupt signal.
# 02:16:54.660 | INFO    | Flow run 'peculiar-bloodhound' - Finished in state Running()
# Exception ignored in: <function _SelectorTransport.__del__ at 0x7fd6a1b18900>
# Traceback (most recent call last):
#   File "/home/stefan/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/asyncio/selector_events.py", line 866, in __del__
#     def __del__(self, _warn=warnings.warn):
#
# KeyboardInterrupt:
#
# KeyboardInterrupt
#
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fd6a0174bd0>>
# Traceback (most recent call last):
#   File "/home/stefan/CRS/CRS.ZarrPipelines/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 808, in _clean_thread_parent_frames
#     if identity not in active_threads:
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# 02:17:01.618 | ERROR   | GlobalEventLoopThread | prefect._internal.concurrency - Service 'EventsWorker' failed to process item Event(occurred=DateTime(2026, 3, 9, 1, 16, 54, 592502, tzinfo=Timezone('UTC')), event='prefect.task-run.Failed', resource=Resource(root={'prefect.resource.id': 'prefect.task-run.019cd027-a5b3-7266-b3b5-90360c1f6390', 'prefect.resource.name': 'score-hazard-fb5', 'prefect.run-count': '3', 'prefect.state-message': 'Task run encountered an exception ValueError: buffer source array is read-only', 'prefect.state-name': 'Failed', 'prefect.state-timestamp': '2026-03-09T01:16:54.592502+00:00', 'prefect.state-type': 'FAILED', 'prefect.orchestration': 'client'}), related=[RelatedResource(root={'prefect.resource.id': 'prefect.flow-run.d23dbd77-ddd0-4b0e-98a1-7119f2266183', 'prefect.resource.role': 'flow-run', 'prefect.resource.name': 'peculiar-bloodhound'}), RelatedResource(root={'prefect.resource.id': 'prefect.flow.5fd16b35-4d82-4743-9e1c-8d5a935d5458', 'prefect.resource.role': 'flow', 'prefect.resource.name': 'crs-score-only'})], payload={'intended': {'from': 'RUNNING', 'to': 'FAILED'}, 'initial_state': {'type': 'RUNNING', 'name': 'Retrying', 'message': '', 'state_details': {}}, 'validated_state': {'type': 'FAILED', 'name': 'Failed', 'message': 'Task run encountered an exception ValueError: buffer source array is read-only', 'state_details': {'retriable': False}, 'data': None}, 'task_run': {'name': 'score-hazard-fb5', 'task_key': 'score_hazard_task-7623e79a', 'dynamic_key': 'fb5ff8d0-429f-4418-8411-a85b0d8a30a9', 'empirical_policy': {'max_retries': 0, 'retry_delay_seconds': 0.0, 'retries': 2, 'retry_delay': 30}, 'tags': [], 'labels': {}, 'task_inputs': {'hazard_code': [], 'scales': []}, 'run_count': 3, 'flow_run_run_count': 1, 'expected_start_time': '2026-03-09T01:13:05.205366Z', 'start_time': '2026-03-09T01:13:05.219726Z', 'end_time': '2026-03-09T01:16:54.592502Z', 'total_run_time': 169.378622}}, id=UUID('019cd02b-25c0-7c50-b5c4-fab12337ec7e'), follows=UUID('019cd02a-f63d-7bed-a0e5-e1fa39ba77f7'))
# --- Error logging to API ---
# All connection attempts failed

# %% [markdown]
# ## Aggregate Only

# %%
# Run individual phases (examples)
# score_only(scales=["100"], hazard_codes=["HS"])       # add/replace one scale
aggregate_only(gadm_levels=[0,1], hazard_codes=["HP","HS","CS","WF","LS","ER","CER","SUB","WS","DR","TC","TS"])  # re-aggregate after rescoring
# Out:
# 23:21:14.819 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8247
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 23:21:18.999 | INFO    | Flow run 'delightful-ringtail' - Beginning flow run 'delightful-ringtail' for flow 'crs-aggregate-only'
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────── Package Info ────────────────────────────────╮
# │                         ╷                                                    │
# │   Package               │ Note                                               │
# │ ╶───────────────────────┼──────────────────────────────────────────────────╴ │
# │   crs-zarrpipelines     │ Wheel built from ~/CRS/CRS.ZarrPipelines           │
# │                         ╵                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 23:24:57.837 | INFO    | distributed.deploy.adaptive - Adaptive scaling started: minimum=10 maximum=30
# 23:24:58.682 | INFO    | Flow run 'delightful-ringtail' - [agg] cluster ready — dashboard: https://cluster-ezliw.dask.host/xUBRr7K8le5E67cK/status
# 23:30:33.524 | INFO    | Task run 'aggregate-hazard-ef2' - Finished in state Completed()
# 23:35:49.970 | INFO    | Task run 'aggregate-hazard-dda' - Finished in state Completed()
# 23:40:42.512 | INFO    | Task run 'aggregate-hazard-374' - Finished in state Completed()
# 23:53:26.012 | INFO    | Task run 'aggregate-hazard-339' - Finished in state Completed()
# 00:13:15.715 | INFO    | Task run 'aggregate-hazard-89e' - Finished in state Completed()
# 00:18:31.061 | INFO    | Task run 'aggregate-hazard-a9c' - Finished in state Completed()
# 00:32:11.575 | INFO    | Task run 'aggregate-hazard-68d' - Finished in state Completed()
# 00:38:35.621 | INFO    | Task run 'aggregate-hazard-a12' - Finished in state Completed()
# 01:04:51.578 | INFO    | Task run 'aggregate-hazard-307' - Finished in state Completed()
# 01:09:38.501 | INFO    | Task run 'aggregate-hazard-820' - Finished in state Completed()
# 01:09:38.565 | INFO    | Flow run 'delightful-ringtail' - Finished in state Completed()

# %%
import fsspec, pandas as pd
with fsspec.open("gs://crs_climate_data_public/production_test/aggregations/SUB_adm1.csv") as f:
    df = pd.read_csv(f)
print(df["scenario"].unique())
print(df["scoring"].unique())
# Out:
# <ArrowStringArray>
# ['RCP85']
# Length: 1, dtype: str
# [ 10 100   5]

# %% [markdown]
# ## Combine Only

# %%
## Rebuild combined final output from all existing CSVs only

# %%
combine_only(gadm_levels=[0,1], scales=["5","10","100"])
# Out:
# 01:43:53.488 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8616
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 01:43:57.878 | INFO    | Flow run 'unbreakable-condor' - Beginning flow run 'unbreakable-condor' for flow 'crs-combine-only'
# 01:45:28.787 | WARNING | app.domain.combine - [CF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/CF_adm0.csv — skipping
# 01:45:30.538 | WARNING | app.domain.combine - [RF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/RF_adm0.csv — skipping
# 01:45:30.918 | WARNING | app.domain.combine - [TC] CSV not found: gs://crs_climate_data_public/production_test/aggregations/TC_adm0.csv — skipping
# 01:45:31.102 | WARNING | app.domain.combine - [TS] CSV not found: gs://crs_climate_data_public/production_test/aggregations/TS_adm0.csv — skipping
# 01:45:31.834 | INFO    | Task run 'combine-scores-2eb' -   scale='5' → five/
# 01:45:31.914 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:45:31.991 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_mean_45.csv (263 rows, 58 cols)
# 01:45:33.023 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:45:33.093 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_max_45.csv (263 rows, 58 cols)
# 01:45:33.359 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:45:33.416 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_std_45.csv (263 rows, 58 cols)
# 01:45:33.882 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_mean_85.csv (263 rows, 58 cols)
# 01:45:34.231 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_max_85.csv (263 rows, 58 cols)
# 01:45:34.549 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_country_std_85.csv (263 rows, 58 cols)
# 01:45:34.799 | INFO    | Task run 'combine-scores-2eb' -   scale='10' → ten/
# 01:45:34.862 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:45:34.930 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_mean_45.csv (263 rows, 58 cols)
# 01:45:35.194 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:45:35.260 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_max_45.csv (263 rows, 58 cols)
# 01:45:35.567 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:45:35.621 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_std_45.csv (263 rows, 58 cols)
# 01:45:36.011 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_mean_85.csv (263 rows, 58 cols)
# 01:45:36.377 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_max_85.csv (263 rows, 58 cols)
# 01:45:36.735 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_country_std_85.csv (263 rows, 58 cols)
# 01:45:36.990 | INFO    | Task run 'combine-scores-2eb' -   scale='100' → hundred/
# 01:45:37.078 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:45:37.334 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_mean_45.csv (263 rows, 58 cols)
# 01:45:37.650 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_mean_85.csv (263 rows, 58 cols)
# 01:45:37.952 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:45:38.199 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_max_45.csv (263 rows, 58 cols)
# 01:45:38.501 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_max_85.csv (263 rows, 58 cols)
# 01:45:38.808 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:45:39.062 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_std_45.csv (263 rows, 58 cols)
# 01:45:39.380 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_country_std_85.csv (263 rows, 58 cols)
# 01:47:42.200 | WARNING | app.domain.combine - [CF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/CF_adm1.csv — skipping
# 01:47:51.675 | WARNING | app.domain.combine - [RF] CSV not found: gs://crs_climate_data_public/production_test/aggregations/RF_adm1.csv — skipping
# 01:47:52.438 | WARNING | app.domain.combine - [TC] CSV not found: gs://crs_climate_data_public/production_test/aggregations/TC_adm1.csv — skipping
# 01:47:52.632 | WARNING | app.domain.combine - [TS] CSV not found: gs://crs_climate_data_public/production_test/aggregations/TS_adm1.csv — skipping
# 01:47:57.394 | INFO    | Task run 'combine-scores-2eb' -   scale='5' → five/
# 01:47:57.600 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:47:57.746 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_mean_45.csv (3662 rows, 62 cols)
# 01:47:58.995 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:47:59.117 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_max_45.csv (3662 rows, 62 cols)
# 01:48:00.349 | WARNING | app.domain.combine - [SUB] No rows for scale=5, scenario=RCP45
# 01:48:00.507 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_std_45.csv (3662 rows, 62 cols)
# 01:48:02.417 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_mean_85.csv (3662 rows, 62 cols)
# 01:48:03.717 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_max_85.csv (3662 rows, 62 cols)
# 01:48:05.050 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/five/hazard_score_province_std_85.csv (3662 rows, 62 cols)
# 01:48:06.596 | INFO    | Task run 'combine-scores-2eb' -   scale='10' → ten/
# 01:48:06.799 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:48:06.925 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_mean_45.csv (3662 rows, 62 cols)
# 01:48:08.150 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:48:08.294 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_max_45.csv (3662 rows, 62 cols)
# 01:48:09.535 | WARNING | app.domain.combine - [SUB] No rows for scale=10, scenario=RCP45
# 01:48:09.674 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_std_45.csv (3662 rows, 62 cols)
# 01:48:11.551 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_mean_85.csv (3662 rows, 62 cols)
# 01:48:12.910 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_max_85.csv (3662 rows, 62 cols)
# 01:48:14.261 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/ten/hazard_score_province_std_85.csv (3662 rows, 62 cols)
# 01:48:15.800 | INFO    | Task run 'combine-scores-2eb' -   scale='100' → hundred/
# 01:48:16.019 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:48:16.540 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_mean_45.csv (3662 rows, 62 cols)
# 01:48:18.072 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_mean_85.csv (3662 rows, 62 cols)
# 01:48:19.743 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:48:20.236 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_max_45.csv (3662 rows, 62 cols)
# 01:48:21.825 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_max_85.csv (3662 rows, 62 cols)
# 01:48:23.515 | WARNING | app.domain.combine - [SUB] No rows for scale=100, scenario=RCP45
# 01:48:24.048 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_std_45.csv (3662 rows, 62 cols)
# 01:48:25.531 | INFO    | Task run 'combine-scores-2eb' -   → gs://crs_climate_data_public/production_test/aggregations/combined/hundred/hazard_score_province_std_85.csv (3662 rows, 62 cols)
# 01:48:26.993 | INFO    | Task run 'combine-scores-2eb' - Finished in state Completed()
# 01:48:27.033 | INFO    | Flow run 'unbreakable-condor' - Finished in state Completed()
